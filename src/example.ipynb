# %%
import py2lean as p2l

# %%
print(p2l.translate_to_lean(p2l.egProgram(), "command"))
# Out:
# Translating source code:
# def f(n):
#     x = n + 1
#     y = x * 2
#     return x + y
#
# Parsed AST:
# Module(
#     body=[
#         FunctionDef(
#             name='f',
#             args=arguments(
#                 posonlyargs=[],
#                 args=[
#                     arg(arg='n')],
#                 kwonlyargs=[],
#                 kw_defaults=[],
#                 defaults=[]),
#             body=[
#                 Assign(
#                     targets=[
#                         Name(id='x', ctx=Store())],
#                     value=BinOp(
#                         left=Name(id='n', ctx=Load()),
#                         op=Add(),
#                         right=Constant(value=1))),
#                 Assign(
#                     targets=[
#                         Name(id='y', ctx=Store())],
#                     value=BinOp(
#                         left=Name(id='x', ctx=Load()),
#                         op=Mult(),
# ...
